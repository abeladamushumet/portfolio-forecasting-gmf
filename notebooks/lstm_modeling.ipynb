# %% [markdown]
# # 1.import

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\hp\Desktop\10 Acadamy\VS code\portfolio-forecasting-gmf\notebooks

# %% [markdown]
# # 2. Settings

# %%
TICKERS = ["TSLA", "BND", "SPY"]
DATA_DIR = os.path.join("..", "data", "processed")  # Adjust if running from notebooks folder
RESULTS_DIR = "results"
os.makedirs(RESULTS_DIR, exist_ok=True)

TEST_SIZE = 30
SEQ_LENGTH = 30

def create_sequences(data, seq_length=SEQ_LENGTH):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

all_metrics = []
all_forecasts = []

# %% [markdown]
# # 3.Check processed data files exist

# %%
print(f"Files in {DATA_DIR}:", os.listdir(DATA_DIR))
for ticker in TICKERS:
    file_path = os.path.join(DATA_DIR, f"{ticker}_processed.csv")
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"Processed data file not found: {file_path}")
    print(f"Found file for {ticker}: {file_path}")
# Out:
# Files in ..\data\processed: ['BND_processed.csv', 'SPY_processed.csv', 'TSLA_processed.csv']
# Found file for TSLA: ..\data\processed\TSLA_processed.csv
# Found file for BND: ..\data\processed\BND_processed.csv
# Found file for SPY: ..\data\processed\SPY_processed.csv

# %% [markdown]
#  # 4. Main loop: Load, preprocess, train LSTM, forecast

# %%
for ticker in TICKERS:
    print(f"\nProcessing {ticker}...")

    # Load processed data
    file_path = os.path.join(DATA_DIR, f"{ticker}_processed.csv")
    df = pd.read_csv(file_path, index_col=0, parse_dates=True)

    ts = df['log_adjclose'].dropna()

    # Train-test split
    train_ts = ts.iloc[:-TEST_SIZE].values.reshape(-1,1)
    test_ts = ts.iloc[-TEST_SIZE:].values.reshape(-1,1)

    # Scale data
    scaler = MinMaxScaler()
    train_scaled = scaler.fit_transform(train_ts)
    test_scaled = scaler.transform(test_ts)

    # Prepare sequences
    X_train, y_train = create_sequences(train_scaled, SEQ_LENGTH)
    test_full = np.concatenate((train_scaled[-SEQ_LENGTH:], test_scaled), axis=0)
    X_test, y_test = create_sequences(test_full, SEQ_LENGTH)

    print(f"Train samples: {X_train.shape[0]}, Test samples: {X_test.shape[0]}")

    # Define LSTM model
    model = Sequential([
        LSTM(50, activation='relu', input_shape=(SEQ_LENGTH,1)),
        Dropout(0.2),
        Dense(1)
    ])

    model.compile(optimizer='adam', loss='mse')

    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Train the model
    history = model.fit(
        X_train, y_train,
        validation_split=0.1,
        epochs=100,
        batch_size=32,
        callbacks=[early_stop],
        verbose=1
    )

    # Predict
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler.inverse_transform(y_pred_scaled)
    y_test_orig = scaler.inverse_transform(y_test)

    # Evaluate
    mae = mean_absolute_error(y_test_orig, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test_orig, y_pred))
    print(f"{ticker} Test MAE: {mae:.4f}, RMSE: {rmse:.4f}")

    all_metrics.append({"Ticker": ticker, "MAE": mae, "RMSE": rmse})

    # Save forecast DataFrame
    forecast_df = pd.DataFrame({
        "Date": ts.index[-len(y_test_orig):],
        "Actual": y_test_orig.flatten(),
        "Forecast": y_pred.flatten(),
        "Ticker": ticker
    }).set_index("Date")

    save_path = os.path.join(RESULTS_DIR, f"forecast_lstm_{ticker}.csv")
    forecast_df.to_csv(save_path)
    print(f"Saved forecast for {ticker} to {save_path}")

    all_forecasts.append(forecast_df)
# Out:
# Processing TSLA...
# Train samples: 2571, Test samples: 30
# C:\Users\hp\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - loss: 0.1044 - val_loss: 0.0049
# Epoch 2/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 0.0098 - val_loss: 0.0052
# Epoch 3/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0101 - val_loss: 0.0048
# Epoch 4/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0092 - val_loss: 0.0049
# Epoch 5/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0090 - val_loss: 0.0048
# Epoch 6/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0090 - val_loss: 0.0051
# Epoch 7/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0091 - val_loss: 0.0047
# Epoch 8/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0087 - val_loss: 0.0046
# Epoch 9/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0086 - val_loss: 0.0051
# Epoch 10/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0087 - val_loss: 0.0045
# Epoch 11/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0080 - val_loss: 0.0045
# Epoch 12/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0081 - val_loss: 0.0045
# Epoch 13/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0087 - val_loss: 0.0044
# Epoch 14/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0086 - val_loss: 0.0044
# Epoch 15/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0078 - val_loss: 0.0043
# Epoch 16/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0077 - val_loss: 0.0043
# Epoch 17/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0073 - val_loss: 0.0043
# Epoch 18/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0071 - val_loss: 0.0043
# Epoch 19/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0073 - val_loss: 0.0041
# Epoch 20/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0073 - val_loss: 0.0041
# Epoch 21/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0074 - val_loss: 0.0041
# Epoch 22/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0072 - val_loss: 0.0041
# Epoch 23/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0075 - val_loss: 0.0041
# Epoch 24/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0069 - val_loss: 0.0040
# Epoch 25/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0068 - val_loss: 0.0043
# Epoch 26/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0063 - val_loss: 0.0040
# Epoch 27/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0072 - val_loss: 0.0040
# Epoch 28/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0065 - val_loss: 0.0039
# Epoch 29/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0067 - val_loss: 0.0041
# Epoch 30/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0069 - val_loss: 0.0043
# Epoch 31/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0071 - val_loss: 0.0039
# Epoch 32/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0063 - val_loss: 0.0039
# Epoch 33/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0063 - val_loss: 0.0038
# Epoch 34/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0059 - val_loss: 0.0037
# Epoch 35/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0061 - val_loss: 0.0037
# Epoch 36/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0062 - val_loss: 0.0037
# Epoch 37/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0062 - val_loss: 0.0039
# Epoch 38/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0061 - val_loss: 0.0037
# Epoch 39/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0062 - val_loss: 0.0038
# Epoch 40/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0061 - val_loss: 0.0036
# Epoch 41/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0058 - val_loss: 0.0036
# Epoch 42/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0058 - val_loss: 0.0035
# Epoch 43/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0060 - val_loss: 0.0035
# Epoch 44/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0063 - val_loss: 0.0035
# Epoch 45/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0060 - val_loss: 0.0036
# Epoch 46/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0056 - val_loss: 0.0035
# Epoch 47/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0059 - val_loss: 0.0036
# Epoch 48/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0055 - val_loss: 0.0035
# Epoch 49/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0057 - val_loss: 0.0034
# Epoch 50/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0057 - val_loss: 0.0034
# Epoch 51/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0058 - val_loss: 0.0037
# Epoch 52/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 53/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0058 - val_loss: 0.0034
# Epoch 54/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0052 - val_loss: 0.0035
# Epoch 55/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0054 - val_loss: 0.0033
# Epoch 56/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 57/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 58/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 59/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0052 - val_loss: 0.0033
# Epoch 60/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 61/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 62/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0052 - val_loss: 0.0033
# Epoch 63/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 64/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0050 - val_loss: 0.0033
# Epoch 65/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0048 - val_loss: 0.0033
# Epoch 66/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0056 - val_loss: 0.0033
# Epoch 67/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 68/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0053 - val_loss: 0.0035
# Epoch 69/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 70/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 71/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 72/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0050 - val_loss: 0.0033
# Epoch 73/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 74/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 75/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0053 - val_loss: 0.0033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# TSLA Test MAE: 0.2251, RMSE: 0.2895
# Saved forecast for TSLA to results\forecast_lstm_TSLA.csv
#
# Processing BND...
# Train samples: 2570, Test samples: 30
# Epoch 1/100
# C:\Users\hp\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - loss: 0.1000 - val_loss: 0.0059
# Epoch 2/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0099 - val_loss: 0.0062
# Epoch 3/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0094 - val_loss: 0.0059
# Epoch 4/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0094 - val_loss: 0.0059
# Epoch 5/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0096 - val_loss: 0.0057
# Epoch 6/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0087 - val_loss: 0.0057
# Epoch 7/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0079 - val_loss: 0.0059
# Epoch 8/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0076 - val_loss: 0.0067
# Epoch 9/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0079 - val_loss: 0.0109
# Epoch 10/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0090 - val_loss: 0.0063
# Epoch 11/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0078 - val_loss: 0.0058
# Epoch 12/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0080 - val_loss: 0.0059
# Epoch 13/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0080 - val_loss: 0.0056
# Epoch 14/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0078 - val_loss: 0.0059
# Epoch 15/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 16/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0076 - val_loss: 0.0057
# Epoch 17/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0073 - val_loss: 0.0057
# Epoch 18/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 19/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0072 - val_loss: 0.0055
# Epoch 20/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 21/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0072 - val_loss: 0.0060
# Epoch 22/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 0.0069 - val_loss: 0.0057
# Epoch 23/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 24/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 0.0073 - val_loss: 0.0054
# Epoch 25/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0069 - val_loss: 0.0054
# Epoch 26/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0068 - val_loss: 0.0058
# Epoch 27/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0072 - val_loss: 0.0056
# Epoch 28/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0068 - val_loss: 0.0054
# Epoch 29/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 0.0067 - val_loss: 0.0056
# Epoch 30/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 31/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 32/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 33/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0065 - val_loss: 0.0053
# Epoch 34/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0065 - val_loss: 0.0053
# Epoch 35/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0066 - val_loss: 0.0053
# Epoch 36/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0066 - val_loss: 0.0053
# Epoch 37/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0061 - val_loss: 0.0055
# Epoch 38/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - loss: 0.0067 - val_loss: 0.0057
# Epoch 39/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0061 - val_loss: 0.0053
# Epoch 40/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 41/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0063 - val_loss: 0.0055
# Epoch 42/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 43/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 44/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 45/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 46/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 47/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0064 - val_loss: 0.0055
# Epoch 48/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 49/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0067 - val_loss: 0.0053
# Epoch 50/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.0061 - val_loss: 0.0053
# Epoch 51/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0069 - val_loss: 0.0052
# Epoch 52/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0069 - val_loss: 0.0052
# Epoch 53/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 54/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 55/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 56/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0065 - val_loss: 0.0052
# Epoch 57/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 58/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0063 - val_loss: 0.0052
# Epoch 59/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 60/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0060 - val_loss: 0.0052
# Epoch 61/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 62/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0062 - val_loss: 0.0052
# Epoch 63/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 64/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0059 - val_loss: 0.0054
# Epoch 65/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 66/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 67/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0066 - val_loss: 0.0054
# Epoch 68/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 69/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 70/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0062 - val_loss: 0.0052
# Epoch 71/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 72/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 73/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0060 - val_loss: 0.0052
# Epoch 74/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 75/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 76/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 77/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0062 - val_loss: 0.0052
# Epoch 78/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 79/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0061 - val_loss: 0.0052
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# BND Test MAE: 0.1210, RMSE: 0.1583
# Saved forecast for BND to results\forecast_lstm_BND.csv
#
# Processing SPY...
# Train samples: 2571, Test samples: 30
# C:\Users\hp\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0755 - val_loss: 0.0111
# Epoch 2/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0123 - val_loss: 0.0105
# Epoch 3/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0114 - val_loss: 0.0117
# Epoch 4/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0116 - val_loss: 0.0105
# Epoch 5/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0117 - val_loss: 0.0114
# Epoch 6/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0114 - val_loss: 0.0099
# Epoch 7/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0110 - val_loss: 0.0099
# Epoch 8/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 9/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0102 - val_loss: 0.0097
# Epoch 10/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0102 - val_loss: 0.0098
# Epoch 11/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0103 - val_loss: 0.0099
# Epoch 12/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0092 - val_loss: 0.0093
# Epoch 13/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0105 - val_loss: 0.0089
# Epoch 14/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0098 - val_loss: 0.0092
# Epoch 15/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0097 - val_loss: 0.0089
# Epoch 16/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0092 - val_loss: 0.0087
# Epoch 17/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 18/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 19/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 20/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0091 - val_loss: 0.0087
# Epoch 21/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0090 - val_loss: 0.0093
# Epoch 22/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0096 - val_loss: 0.0086
# Epoch 23/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0090 - val_loss: 0.0085
# Epoch 24/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0089 - val_loss: 0.0089
# Epoch 25/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 26/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0090 - val_loss: 0.0090
# Epoch 27/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0084 - val_loss: 0.0083
# Epoch 28/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 29/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 30/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 31/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0086 - val_loss: 0.0091
# Epoch 32/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0092 - val_loss: 0.0085
# Epoch 33/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0082 - val_loss: 0.0085
# Epoch 34/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0084 - val_loss: 0.0086
# Epoch 35/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0076 - val_loss: 0.0091
# Epoch 36/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 37/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0077 - val_loss: 0.0090
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# SPY Test MAE: 0.1414, RMSE: 0.1662
# Saved forecast for SPY to results\forecast_lstm_SPY.csv

# %% [markdown]
# # 5. Combine all forecasts and metrics

# %%
combined_forecasts = pd.concat(all_forecasts)
combined_forecasts.to_csv(os.path.join(RESULTS_DIR, "forecasts_lstm_all.csv"))

metrics_df = pd.DataFrame(all_metrics)
metrics_df.to_csv(os.path.join(RESULTS_DIR, "metrics_lstm_all.csv"), index=False)

print("\nAll tickers processed.")
print(metrics_df)
# Out:
# All tickers processed.
#   Ticker       MAE      RMSE
# 0   TSLA  0.225054  0.289491
# 1    BND  0.120981  0.158341
# 2    SPY  0.141365  0.166203
